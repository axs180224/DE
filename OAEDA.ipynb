# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\anand\\Downloads\\archive (4)\\data.csv")

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
#Looking at overall data
data.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
print(data.isnull().sum())
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
data = data.drop(['Market Category', 'Engine HP', 'Engine Cylinders'], axis = 1)

# %%
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type Transmission Type  \
# 0  BMW  1 Series M  2011  premium unleaded (required)            MANUAL
# 1  BMW    1 Series  2011  premium unleaded (required)            MANUAL
# 2  BMW    1 Series  2011  premium unleaded (required)            MANUAL
# 3  BMW    1 Series  2011  premium unleaded (required)            MANUAL
# 4  BMW    1 Series  2011  premium unleaded (required)            MANUAL
#
#       Driven_Wheels  Number of Doors Vehicle Size Vehicle Style  highway MPG  \
# 0  rear wheel drive              2.0      Compact         Coupe           26
# 1  rear wheel drive              2.0      Compact   Convertible           28
# 2  rear wheel drive              2.0      Compact         Coupe           28
# 3  rear wheel drive              2.0      Compact         Coupe           28
# 4  rear wheel drive              2.0      Compact   Convertible           28
#
#    city mpg  Popularity   MSRP
# 0        19        3916  46135
# ...

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  \
# 0          BMW  1 Series M  2011     premium unleaded (required)
# 1          BMW    1 Series  2011     premium unleaded (required)
# 2          BMW    1 Series  2011     premium unleaded (required)
# 3          BMW    1 Series  2011     premium unleaded (required)
# 4          BMW    1 Series  2011     premium unleaded (required)
# ...        ...         ...   ...                             ...
# 11909    Acura         ZDX  2012     premium unleaded (required)
# 11910    Acura         ZDX  2012     premium unleaded (required)
# 11911    Acura         ZDX  2012     premium unleaded (required)
# 11912    Acura         ZDX  2013  premium unleaded (recommended)
# 11913  Lincoln      Zephyr  2006                regular unleaded
#
#       Transmission Type      Driven_Wheels  Number of Doors Vehicle Size  \
# 0                MANUAL   rear wheel drive              2.0      Compact
# ...

# %%
data['Make'].value_counts()
# Out:
# Make
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
data.plot(kind= 'hist', y= 'Year')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot.pie(y= 'Make')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data.plot.pie(y= 'Make')
#
# File c:\Users\anand\Skil\.venv\lib\site-packages\pandas\plotting\_core.py:1658, in PlotAccessor.pie(self, **kwargs)
#    1652 if (
#    1653     isinstance(self._parent, ABCDataFrame)
#    1654     and kwargs.get("y", None) is None
#    1655     and not kwargs.get("subplots", False)
#    1656 ):
#    1657     raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1658 return self(kind="pie", **kwargs)
#
# File c:\Users\anand\Skil\.venv\lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...
